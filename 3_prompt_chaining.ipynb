# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0)

# %%
#define state
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState) -> BlogState:

    title = state['title']
    prompt = f"Create a detailed outline for a blog post about: {title}"
    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state:BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']
    prompt = f"Write a comprehensive blog based on the title : {title} using the following outline: {outline}"
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

# %%
workflow = graph.compile()

# %%
#execute workflow
initial_state = {"title": "Rise of Artificial Intelligence in India"}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of Artificial Intelligence in India', 'outline': 'I. Introduction\n    A. Brief overview of artificial intelligence (AI)\n    B. Explanation of the rise of AI in India\n    C. Thesis statement: The increasing adoption of AI technology in India is transforming various industries and shaping the future of the country.\n\nII. Historical background of AI in India\n    A. Early developments in AI research and education in India\n    B. Government initiatives to promote AI technology in the country\n    C. Growth of AI startups and companies in India\n\nIII. Impact of AI on various industries in India\n    A. Healthcare sector\n        1. Use of AI in medical diagnosis and treatment\n        2. AI-powered healthcare solutions for remote areas\n    B. Education sector\n        1. AI-based learning platforms and personalized education\n        2. AI-driven assessment and evaluation systems\n    C. Banking and finance sector\n        1. AI-powered chatbots for customer service\n        2. Fraud detection and risk management using AI algorithms\n    D. Manufacturing sector\n        1. Automation of production processes with AI technology\n        2. Predictive maintenance and quality control using AI\n\nIV. Challenges and opportunities of AI adoption in India\n    A. Ethical concerns related to AI technology\n        1. Data privacy and security issues\n        2. Bias and discrimination in AI algorithms\n    B. Skills gap in AI workforce in India\n        1. Need for specialized training and education in AI\n        2. Opportunities for job creation in AI-related fields\n    C. Potential for AI to drive economic growth and innovation in India\n\nV. Future outlook of AI in India\n    A. Predictions for the growth of AI technology in India\n    B. Potential areas for further development and investment in AI\n    C. Importance of collaboration between government, industry, and academia to harness the full potential of AI in India\n\nVI. Conclusion\n    A. Recap of key points discussed in the blog post\n    B. Call to action for readers to stay informed and engaged with the latest developments in AI in India\n    C. Final thoughts on the transformative power of AI technology in shaping the future of India.', 'content': 'Artificial Intelligence (AI) is a rapidly evolving technology that is revolutionizing various industries around the world. In India, the adoption of AI technology is on the rise, with the country emerging as a key player in the global AI landscape. The increasing use of AI in India is transforming industries such as healthcare, education, banking and finance, and manufacturing, and shaping the future of the country in profound ways.\n\nHistorically, India has made significant strides in AI research and education. The country has a strong foundation in mathematics and computer science, which has laid the groundwork for advancements in AI technology. Government initiatives to promote AI technology in India, such as the National AI Portal and the National AI Strategy, have further fueled the growth of AI in the country. Additionally, the rise of AI startups and companies in India has contributed to the development of a vibrant AI ecosystem.\n\nThe impact of AI on various industries in India is significant. In the healthcare sector, AI is being used for medical diagnosis and treatment, as well as for developing AI-powered healthcare solutions for remote areas. In the education sector, AI-based learning platforms and personalized education are transforming the way students learn and teachers teach. In the banking and finance sector, AI-powered chatbots are improving customer service, while AI algorithms are being used for fraud detection and risk management. In the manufacturing sector, AI technology is automating production processes and enabling predictive maintenance and quality control.\n\nDespite the numerous benefits of AI technology, there are also challenges that need to be addressed. Ethical concerns rel ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of artificial intelligence (AI)
#     B. Explanation of the rise of AI in India
#     C. Thesis statement: The increasing adoption of AI technology in India is transforming various industries and shaping the future of the country.
#
# II. Historical background of AI in India
#     A. Early developments in AI research and education in India
#     B. Government initiatives to promote AI technology in the country
#     C. Growth of AI startups and companies in India
#
# III. Impact of AI on various industries in India
#     A. Healthcare sector
#         1. Use of AI in medical diagnosis and treatment
#         2. AI-powered healthcare solutions for remote areas
#     B. Education sector
#         1. AI-based learning platforms and personalized education
#         2. AI-driven assessment and evaluation systems
#     C. Banking and finance sector
#         1. AI-powered chatbots for customer service
#         2. Fraud detection and risk management using AI algorithms
#     D. Manufacturing sector
#         1. Automation of production processes with AI technology
#         2. Predictive maintenance and quality control using AI
#
# IV. Challenges and opportunities of AI adoption in India
#     A. Ethical concerns related to AI technology
#         1. Data privacy and security issues
#         2. Bias and discrimination in AI algorithms
#     B. Skills gap in AI workforce in India
#         1. Need for specialized training and education in AI
#         2. Opportunities for job creation in AI-related fields
#     C. Potential for AI to drive economic growth and innovation in India
#
# V. Future outlook of AI in India
#     A. Predictions for the growth of AI technology in India
#     B. Potential areas for further development and investment in AI
#     C. Importance of collaboration between government, industry, and academia to harness the full potential of AI in India
#
# VI. Conclusion
#     A. Recap of key points discussed in the blog post
#     B. Call to action for readers to stay informed and engaged with the latest developments in AI in India
#     C. Final thoughts on the transformative power of AI technology in shaping the future of India.

# %%
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) is a rapidly evolving technology that is revolutionizing various industries around the world. In India, the adoption of AI technology is on the rise, with the country emerging as a key player in the global AI landscape. The increasing use of AI in India is transforming industries such as healthcare, education, banking and finance, and manufacturing, and shaping the future of the country in profound ways.
#
# Historically, India has made significant strides in AI research and education. The country has a strong foundation in mathematics and computer science, which has laid the groundwork for advancements in AI technology. Government initiatives to promote AI technology in India, such as the National AI Portal and the National AI Strategy, have further fueled the growth of AI in the country. Additionally, the rise of AI startups and companies in India has contributed to the development of a vibrant AI ecosystem.
#
# The impact of AI on various industries in India is significant. In the healthcare sector, AI is being used for medical diagnosis and treatment, as well as for developing AI-powered healthcare solutions for remote areas. In the education sector, AI-based learning platforms and personalized education are transforming the way students learn and teachers teach. In the banking and finance sector, AI-powered chatbots are improving customer service, while AI algorithms are being used for fraud detection and risk management. In the manufacturing sector, AI technology is automating production processes and enabling predictive maintenance and quality control.
#
# Despite the numerous benefits of AI technology, there are also challenges that need to be addressed. Ethical concerns related to AI, such as data privacy and security issues, as well as bias and discrimination in AI algorithms, need to be carefully managed. There is also a skills gap in the AI workforce in India, highlighting the need for specialized training and education in AI. However, the adoption of AI technology in India presents opportunities for job creation and economic growth, as well as the potential for driving innovation in various industries.
#
# Looking towards the future, the growth of AI technology in India is expected to continue at a rapid pace. Predictions for the future of AI in India include further advancements in AI technology, as well as potential areas for further development and investment in AI. Collaboration between government, industry, and academia will be crucial in harnessing the full potential of AI in India and driving the country towards a more technologically advanced future.
#
# In conclusion, the rise of Artificial Intelligence in India is transforming various industries and shaping the future of the country. It is important for readers to stay informed and engaged with the latest developments in AI in India, as the transformative power of AI technology has the potential to drive economic growth, innovation, and societal change in the country. By embracing AI technology and addressing the challenges it presents, India can position itself as a global leader in the AI landscape and pave the way for a brighter future.
